# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df1 = pd.read_csv('iris.csv')
df1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.scatterplot(x="PetalLengthCm", y="SepalLengthCm", style="Species", data=df1)

# %% [markdown]
# What possible clusters do you see with the naked eye? How do they relate to the three species?
# You see a clear cluster for the Iris-setosa species, but the other species (Iris-versicolor and Iris-virginica) are not as clustered as Iris-setosa. The versicolor and virginica sort of flow into one another.

# %%
km = KMeans(n_clusters=3)
X = df[['SepalLengthCm','PetalLengthCm']] #get the X variables from the dataframe
km = km.fit(X) #calculate the cluster centers
df['cluster'] = km.predict(X) #predict the clusters of each observation and store in the dataframe
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    cluster
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
sns.scatterplot(x="PetalLengthCm", y="SepalLengthCm", style="Species", hue='cluster', data=df)

# %% [markdown]
# How does k-means perform?
# What you see is that cluster 1 has a serious outlier. For the other cluster it is sort of difficult to see where exactly the divide between the clusters is.

# %%
km = KMeans(n_clusters=4)
X = df[['SepalLengthCm','PetalLengthCm']] #get the X variables from the dataframe
km = km.fit(X) #calculate the cluster centers
df['cluster'] = km.predict(X) #predict the clusters of each observation and store in the dataframe
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    cluster
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
sns.scatterplot(x="PetalLengthCm", y="SepalLengthCm", style="Species", hue='cluster', data=df)

# %% [markdown]
# The natural number of clusters is 4
