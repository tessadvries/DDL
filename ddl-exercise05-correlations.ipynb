# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr

# %%
df = pd.read_csv("funda-amsterdam.csv")
df.head()
# Out:
#    Unnamed: 0                         address  area  bedrooms postal_code  \
# 0           0       Knollendamstraat 4 III/IV   108         2     1013 TN
# 1           1             Moerdijkstraat 47 1    47         1     1079 XM
# 2           2               Zeeburgerdijk 349   116         2     1095 AD
# 3           3          Brederodestraat 124 -1    58         2     1054 VH
# 4           4  Admiraal De Ruijterweg 409 III    63         1     1055 MD
#
#   posting_date   price property_type  rooms  sale_date  \
# 0     4-6-2016  510000     apartment      3  23-6-2016
# 1    22-6-2016  215000     apartment      2   5-7-2016
# 2     9-6-2016  325000     apartment      3   8-7-2016
# 3    14-5-2016  315000     apartment      3   2-6-2016
# 4    14-6-2016  200000     apartment      3  23-6-2016
#
#                                                  url  year_built
# 0  http://www.funda.nl/koop/verkocht/amsterdam/ap...        1906
# ...

# %%
#making a subset of three quantitative variables.
df_subset = df[["price", "area", "rooms"]]
df_subset.head()
# Out:
#     price  area  rooms
# 0  510000   108      3
# 1  215000    47      2
# 2  325000   116      3
# 3  315000    58      3
# 4  200000    63      3

# %%
#make a scatterplot matrix of the subset with three quantitative variables.
sns.pairplot(df_subset)

# %%
#scatterplot of the quantitative variables 'area' and 'price'.
sns.scatterplot(x="area", y="price", data=df)
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Area in correlation with price')
# Out:
# Text(0.5,1,'Area in correlation with price')

# %%
#eliminating 'wrong' data from the subset to get a more realistic dataset, and creating a new subset and making a scatterplot of this. 
df_subset2 = df_subset2[df_subset2["price"]>30000] 
df_subset2 = df_subset2[df_subset2["area"]>0]
df_subset2.head()
sns.scatterplot(x="area", y="price", data=df_subset2)
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Area in correlation with price')
# Out:
# Text(0.5,1,'Area in correlation with price')

# %% [markdown]
# The relation is somewhat linear, the points lie around a virtual line. <br>
# However, the variation seems to increase with higher pricing and larger area.

# %%
#calculating pearson's r.
pearsonr(df_subset2["area"], df_subset2["price"])
# Out:
# (0.7250807666953685, 0.0)

# %% [markdown]
# r is 0.73, and p is 0. From this we can conclude the following: <br>
# The area and price are strongly correlated (r = 0.73) <br>
# The correlation is highly significant (p < 0.001)

# %% [markdown]
# <b>Conclusion</b> <br>
# From this it is possible to conclude that the variables price and area hold a strong relation with eachother. The area of an appartment/house influences the price of the appartment/house.
